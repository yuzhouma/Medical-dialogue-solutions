# %%
import subprocess
import time
from datetime import timedelta
import os
import sys
'''
CUDA_VISIBLE_DEVICES=0 nohup bash -c \"swift sft --model Qwen/Qwen2.5-7B-Instruct --train_type lora --dataset '/mnt/workspace/final_data/train.json' --torch_dtype bfloat16 --quant_method hqq --quant_bits 4 --num_train_epochs 1 --per_device_train_batch_size 2 --per_device_eval_batch_size 1 --learning_rate 1e-4 --lora_rank 8 --lora_alpha 32 --target_modules all-linear --gradient_accumulation_steps 16 --eval_steps 50 --save_steps 50 --save_total_limit 2 --logging_steps 5 --max_length 1024 --output_dir output --system 'You are a helpful assistant.' --warmup_ratio 0.05 --dataloader_num_workers 4 --model_author swift --model_name swift-robot\" &
'''


def run_swift_sft():
    # 记录开始时间
    start_time = time.time()
    print(f"开始时间: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start_time))}\n")
    
    # 构建要执行的命令列表
    command_list = [
        "swift", "sft",
        "--model", "Qwen/Qwen2.5-7B-Instruct",
        "--train_type", "lora",
        "--dataset", "/mnt/workspace/final_data/train.json",
        "--torch_dtype", "bfloat16",
        "--num_train_epochs", "1",
        "--per_device_train_batch_size", "1",
        "--learning_rate", "1e-4",
        "--lora_rank", "8",
        "--lora_alpha", "32",
        "--seed", "42",
        "--gradient_accumulation_steps", "16",
        "--eval_steps", "50",
        "--save_steps", "50",
        "--save_total_limit", "2",
        "--logging_steps", "5",
        "--max_length", "1024",
        "--output_dir", "output",
        "--warmup_ratio", "0.05",
        "--dataloader_num_workers", "4",
        "--model_author", "swift",
        "--model_name", "swift-robot"
    ]
    
    # 显示命令回显
    print("即将执行的命令:")
    print(f"CUDA_VISIBLE_DEVICES=0 { ' '.join(command_list) }\n")
    print("开始执行命令，实时日志如下：\n")
    
    try:
        # 设置环境变量
        env = dict(os.environ)
        env["CUDA_VISIBLE_DEVICES"] = "0"
        
        # 执行命令并实时输出日志
        process = subprocess.Popen(
            command_list,
            env=env,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1  # 行缓冲
        )
        
        # 实时读取并打印输出
        for line in process.stdout:
            print(line, end='')  # end='' 避免重复换行
            sys.stdout.flush()  # 强制刷新输出缓冲区
            
        # 等待进程完成并获取返回码
        return_code = process.wait()
        if return_code != 0:
            raise subprocess.CalledProcessError(return_code, command_list)
        
    except subprocess.CalledProcessError as e:
        print(f"\n\n命令执行出错，返回码: {e.returncode}")
        return
    except Exception as e:
        print(f"\n\n发生异常: {e}")
        return
    
    # 记录结束时间
    end_time = time.time()
    print(f"\n\n结束时间: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(end_time))}")
    
    # 计算并输出时间差
    elapsed_time = end_time - start_time
    print(f"总执行时间: {timedelta(seconds=int(elapsed_time))}")

if __name__ == "__main__":
    run_swift_sft()
# Out:
# 开始时间: 2025-09-28 09:58:44
#
# 即将执行的命令:
# CUDA_VISIBLE_DEVICES=0 swift sft --model Qwen/Qwen2.5-7B-Instruct --train_type lora --dataset /mnt/workspace/final_data/train.json --torch_dtype bfloat16 --num_train_epochs 1 --per_device_train_batch_size 1 --learning_rate 1e-4 --lora_rank 8 --lora_alpha 32 --seed 42 --gradient_accumulation_steps 16 --eval_steps 50 --save_steps 50 --save_total_limit 2 --logging_steps 5 --max_length 1024 --output_dir output --warmup_ratio 0.05 --dataloader_num_workers 4 --model_author swift --model_name swift-robot
#
# 开始执行命令，实时日志如下：
#
# run sh: `/usr/local/bin/python /usr/local/lib/python3.11/site-packages/swift/cli/sft.py --model Qwen/Qwen2.5-7B-Instruct --train_type lora --dataset /mnt/workspace/final_data/train.json --torch_dtype bfloat16 --num_train_epochs 1 --per_device_train_batch_size 1 --learning_rate 1e-4 --lora_rank 8 --lora_alpha 32 --seed 42 --gradient_accumulation_steps 16 --eval_steps 50 --save_steps 50 --save_total_limit 2 --logging_steps 5 --max_length 1024 --output_dir output --warmup_ratio 0.05 --dataloader_num_workers 4 --model_author swift --model_name swift-robot`
# [INFO:swift] Successfully registered `/usr/local/lib/python3.11/site-packages/swift/llm/dataset/data/dataset_info.json`.
# [INFO:swift] rank: -1, local_rank: -1, world_size: 1, local_world_size: 1
# [INFO:swift] Downloading the model from ModelScope Hub, model_id: Qwen/Qwen2.5-7B-Instruct
# Downloading Model from https://www.modelscope.cn to directory: /mnt/workspace/.cache/modelscope/models/Qwen/Qwen2.5-7B-Instruct
# [INFO:modelscope] Target directory already exists, skipping creation.
# [INFO:swift] Loading the model using model_dir: /mnt/workspace/.cache/modelscope/models/Qwen/Qwen2___5-7B-Instruct
# [INFO:swift] Setting args.lazy_tokenize: False
# [INFO:swift] output_dir: /mnt/workspace/output/v3-20250928-095853
# [INFO:swift] Global seed set to 42
# [INFO:swift] args: TrainArguments(
# _n_gpu=-1,
# acc_strategy=token,
# accelerator_config={'dispatch_batches': False},
# adafactor=False,
# adalora_beta1=0.85,
# adalora_beta2=0.85,
# adalora_deltaT=1,
# adalora_init_r=12,
# adalora_orth_reg_weight=0.5,
# adalora_target_r=8,
# adalora_tfinal=0,
# adalora_tinit=0,
# adam_beta1=0.9,
# adam_beta2=0.95,
# adam_epsilon=1e-08,
# adapter_act=gelu,
# adapter_length=128,
# adapters=[],
# add_version=True,
# agent_template=None,
# aligner_lr=None,
# attn_impl=None,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=True,
# bf16_full_eval=False,
# bnb_4bit_compute_dtype=torch.bfloat16,
# bnb_4bit_quant_storage=None,
# bnb_4bit_quant_type=nf4,
# bnb_4bit_use_double_quant=True,
# boft_block_num=0,
# boft_block_size=4,
# boft_dropout=0.0,
# boft_n_butterfly_factor=1,
# cached_dataset=[],
# channels=None,
# check_model=True,
# ckpt_dir=None,
# columns={},
# create_checkpoint_symlink=False,
# custom_dataset_info=[],
# custom_register_path=[],
# data_seed=42,
# dataloader_drop_last=False,
# dataloader_num_workers=4,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# dataset=['/mnt/workspace/final_data/train.json'],
# dataset_num_proc=1,
# dataset_shuffle=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=18000000,
# debug=None,
# deepspeed=None,
# deepspeed_autotp_size=None,
# device_map=None,
# disable_tqdm=None,
# do_eval=False,
# do_predict=False,
# do_train=False,
# download_mode=reuse_dataset_if_exists,
# ds3_gather_for_generation=True,
# eval_accumulation_steps=None,
# eval_dataset=[],
# eval_dataset_args=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_generation_config=None,
# eval_limit=None,
# eval_on_start=False,
# eval_steps=50.0,
# eval_strategy=no,
# eval_use_evalscope=False,
# eval_use_gather_object=False,
# external_plugins=[],
# fourier_n_frequency=2000,
# fourier_scaling=300.0,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# freeze_aligner=True,
# freeze_llm=False,
# freeze_parameters=[],
# freeze_parameters_ratio=0.0,
# freeze_parameters_regex=None,
# freeze_vit=True,
# fsdp=,
# fsdp_config=None,
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# galore_cos_threshold=0.4,
# galore_gamma_proj=2,
# galore_optim_per_parameter=False,
# galore_proj_bits=4,
# galore_proj_group_size=256,
# galore_proj_quant=False,
# galore_proj_type=std,
# galore_quantization=False,
# galore_queue_size=5,
# galore_rank=128,
# galore_scale=1.0,
# galore_target_modules=None,
# galore_update_proj_gap=50,
# galore_with_embedding=False,
# generation_config=None,
# generation_max_length=None,
# generation_num_beams=None,
# gradient_accumulation_steps=16,
# gradient_checkpointing=True,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# group_by_length=False,
# half_precision_backend=auto,
# hqq_axis=None,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_args_error=False,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# init_strategy=None,
# init_weights=True,
# interleave_prob=None,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# lazy_tokenize=False,
# learning_rate=0.0001,
# length_column_name=length,
# liger_kernel_config=None,
# lisa_activated_layers=0,
# lisa_step_interval=20,
# llamapro_num_groups=None,
# llamapro_num_new_blocks=4,
# load_args=False,
# load_best_model_at_end=False,
# load_data_args=False,
# load_from_cache_file=True,
# local_rank=-1,
# local_repo_path=None,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/mnt/workspace/output/v3-20250928-095853/runs,
# logging_first_step=True,
# logging_nan_inf_filter=True,
# logging_steps=5,
# logging_strategy=steps,
# logprobs=False,
# lora_alpha=32,
# lora_bias=none,
# lora_dropout=0.05,
# lora_dtype=None,
# lora_ga_batch_size=2,
# lora_ga_direction=ArB2r,
# lora_ga_iters=2,
# lora_ga_max_length=1024,
# lora_ga_scale=stable,
# lora_ga_stable_gamma=16,
# lora_modules=[],
# lora_rank=8,
# lorap_lr_ratio=None,
# loss_scale=default,
# loss_type=None,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=cosine,
# max_epochs=None,
# max_grad_norm=1.0,
# max_length=1024,
# max_memory={},
# max_model_len=None,
# max_new_tokens=64,
# max_pixels=None,
# max_steps=-1,
# metric=None,
# metric_for_best_model=loss,
# model=Qwen/Qwen2.5-7B-Instruct,
# model_author=['swift'],
# model_kwargs={},
# model_name=['swift-robot'],
# model_revision=None,
# model_type=qwen2_5,
# modules_to_save=[],
# mp_parameters=,
# neftune_noise_alpha=None,
# new_special_tokens=[],
# no_cuda=False,
# norm_bbox=None,
# num_beams=1,
# num_labels=None,
# num_train_epochs=1.0,
# optim=adamw_torch,
# optim_args=None,
# optim_target_modules=None,
# optimizer=None,
# output_dir=/mnt/workspace/output/v3-20250928-095853,
# overwrite_output_dir=False,
# packing=False,
# padding_free=False,
# padding_side=right,
# past_index=-1,
# per_device_eval_batch_size=1,
# per_device_train_batch_size=1,
# predict_with_generate=False,
# prediction_loss_only=False,
# problem_type=None,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# quant_bits=None,
# quant_method=None,
# ray_scope=last,
# reft_args=None,
# reft_intervention_type=LoreftIntervention,
# reft_layer_key=None,
# reft_layers=None,
# reft_rank=4,
# remove_unused_columns=True,
# repetition_penalty=None,
# report_to=['tensorboard'],
# response_prefix=None,
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# resume_only_model=False,
# rope_scaling=None,
# router_aux_loss_coef=0.0,
# run_name=/mnt/workspace/output/v3-20250928-095853,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=50.0,
# save_strategy=steps,
# save_total_limit=2,
# seed=42,
# sequence_parallel_size=1,
# shuffle_buffer_size=1000,
# skip_memory_metrics=True,
# sortish_sampler=False,
# split_dataset_ratio=0.0,
# stop_words=[],
# stopping_strategy=first_exhausted,
# stream=False,
# streaming=False,
# strict=False,
# swanlab_exp_name=None,
# swanlab_lark_secret=None,
# swanlab_lark_webhook_url=None,
# swanlab_mode=cloud,
# swanlab_project=None,
# swanlab_token=<SWANLAB_TOKEN>,
# swanlab_workspace=None,
# system=None,
# target_modules=['all-linear'],
# target_regex=None,
# task_type=causal_lm,
# temperature=0.0,
# template=qwen2_5,
# template_backend=swift,
# tf32=None,
# top_k=None,
# top_logprobs=None,
# top_p=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_dtype=torch.bfloat16,
# torch_empty_cache_steps=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# train_dataloader_shuffle=True,
# train_type=lora,
# trainable_parameters=[],
# trainable_parameters_regex=None,
# truncation_strategy=delete,
# tuner_backend=peft,
# use_chat_template=True,
# use_cpu=False,
# use_dora=False,
# use_galore=False,
# use_hf=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_liger_kernel=False,
# use_logits_to_keep=None,
# use_mps_device=False,
# use_rslora=False,
# use_swift_lora=False,
# val_dataset=[],
# val_dataset_shuffle=False,
# vera_d_initial=0.1,
# vera_dropout=0.0,
# vera_projection_prng_key=0,
# vera_rank=256,
# vit_gradient_checkpointing=None,
# vit_lr=None,
# warmup_ratio=0.05,
# warmup_steps=0,
# weight_decay=0.1,
# zero_hpz_partition_size=None,
# )
# [INFO:swift] Downloading the model from ModelScope Hub, model_id: Qwen/Qwen2.5-7B-Instruct
# Downloading Model from https://www.modelscope.cn to directory: /mnt/workspace/.cache/modelscope/models/Qwen/Qwen2.5-7B-Instruct
# [INFO:modelscope] Target directory already exists, skipping creation.
# [INFO:swift] Loading the model using model_dir: /mnt/workspace/.cache/modelscope/models/Qwen/Qwen2___5-7B-Instruct
# [INFO:swift] model_kwargs: {'device_map': 'cuda:0'}
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:43<02:10, 43.35s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [01:33<01:34, 47.22s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [02:11<00:43, 43.31s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [02:50<00:00, 41.45s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [02:50<00:00, 42.64s/it]
# [INFO:swift] model.hf_device_map: {'': device(type='cuda', index=0)}
# [INFO:swift] model_info: ModelInfo(model_type='qwen2_5', model_dir='/mnt/workspace/.cache/modelscope/models/Qwen/Qwen2___5-7B-Instruct', torch_dtype=torch.bfloat16, max_model_len=32768, quant_method=None, quant_bits=None, rope_scaling=None, is_moe_model=False, config=Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 3584,
#   "initializer_range": 0.02,
#   "intermediate_size": 18944,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 28,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 4,
#   "pad_token_id": 151643,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.55.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 152064
# }
# , task_type='causal_lm', num_labels=None)
# [INFO:swift] model.generation_config: GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "max_new_tokens": 64,
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.05
# }
#
# [INFO:swift] default_system: 'You are Qwen, created by Alibaba Cloud. You are a helpful assistant.'
# [INFO:swift] max_length: 1024
# [INFO:swift] response_prefix: ''
# [INFO:swift] agent_template: hermes
# [INFO:swift] Start time of running main: 2025-09-28 10:01:45.986334
# [INFO:swift] swift.__version__: 3.7.1
# [INFO:swift] SelfCognitionPreprocessor has been successfully configured with name: ('swift-robot', 'swift-robot'), author: ('swift', 'swift').
# [INFO:swift] train_dataset: Dataset({
#     features: ['messages'],
#     num_rows: 37361
# })
# [INFO:swift] val_dataset: None
# [INFO:swift] Dataset filtered, origin length: 37361, filtered dataset length: 37181
# [INFO:swift] [INPUT_IDS] [151644, 8948, 198, 2610, 525, 1207, 16948, 11, 3465, 553, 54364, 14817, 13, 1446, 525, 264, 10950, 17847, 13, 151645, 198, 151644, 872, 198, 99601, 56568, 101909, 106045, 104391, 103998, 37945, 100345, 101924, 103936, 107485, 99912, 9370, 100182, 101898, 28311, 70108, 3837, 19, 16, 92015, 3837, 91777, 20412, 100347, 99389, 102395, 102072, 3837, 104373, 85336, 101071, 106012, 101743, 120449, 100575, 37945, 56007, 18830, 101743, 120449, 100575, 105184, 101368, 20412, 99387, 100535, 151645, 198, 151644, 77091, 198, 101743, 120449, 100575, 73670, 110966, 42192, 100406, 99389, 102395, 3837, 104047, 18830, 102395, 64952, 102395, 99508, 102395, 100406, 101368, 3837, 103929, 101368, 102410, 20412, 102395, 45995, 101304, 100631, 113801, 3837, 101898, 56568, 112189, 99190, 102395, 106307, 33108, 99414, 71304, 104857, 101071, 3837, 114671, 113422, 87256, 71817, 101899, 1773, 99604, 113422, 100771, 101970, 101368, 3837, 101924, 85106, 100345, 101960, 106141, 104883, 26939, 105327, 44991, 100043, 100634, 71817, 72448, 101931, 9370, 101071, 3837, 109095, 32664, 99769, 101899, 1773, 104043, 101924, 101254, 85106, 104466, 118681, 5373, 101906, 99287, 100718, 114331, 99257, 5373, 101254, 104579, 108851, 116283, 101474, 64272, 106232, 5373, 100259, 107663, 33108, 42140, 100399, 103265, 1773, 151645]
# [INFO:swift] [INPUT] <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# 现在你是一个肿瘤学科医生，请根据患者的问题给出实际的医疗建议：
# 男，41岁，老是出现血尿的情况，昨天去检查说是膀胱癌，请问有膀胱癌早期症状是怎样的<|im_end|>
# <|im_start|>assistant
# 膀胱癌可以表现为无痛血尿，也可以有尿频尿急尿痛症状，你的症状有可能是尿路感染或者结石，建议你去医院做尿常规和彩超仔细检查，查明病因再进行治疗。不同病因引起不同的症状，患者需要根据自身病情尽快到正规三甲医院进行系统规范的检查，这样才能对症治疗。此外患者日常需要规律作息、做好防寒保暖工作、日常饮食多吃清淡稀软的食物、勤通风和多喝热水。<|im_end|>
# [INFO:swift] [LABELS_IDS] [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 101743, 120449, 100575, 73670, 110966, 42192, 100406, 99389, 102395, 3837, 104047, 18830, 102395, 64952, 102395, 99508, 102395, 100406, 101368, 3837, 103929, 101368, 102410, 20412, 102395, 45995, 101304, 100631, 113801, 3837, 101898, 56568, 112189, 99190, 102395, 106307, 33108, 99414, 71304, 104857, 101071, 3837, 114671, 113422, 87256, 71817, 101899, 1773, 99604, 113422, 100771, 101970, 101368, 3837, 101924, 85106, 100345, 101960, 106141, 104883, 26939, 105327, 44991, 100043, 100634, 71817, 72448, 101931, 9370, 101071, 3837, 109095, 32664, 99769, 101899, 1773, 104043, 101924, 101254, 85106, 104466, 118681, 5373, 101906, 99287, 100718, 114331, 99257, 5373, 101254, 104579, 108851, 116283, 101474, 64272, 106232, 5373, 100259, 107663, 33108, 42140, 100399, 103265, 1773, 151645]
# [INFO:swift] [LABELS] [-100 * 76]膀胱癌可以表现为无痛血尿，也可以有尿频尿急尿痛症状，你的症状有可能是尿路感染或者结石，建议你去医院做尿常规和彩超仔细检查，查明病因再进行治疗。不同病因引起不同的症状，患者需要根据自身病情尽快到正规三甲医院进行系统规范的检查，这样才能对症治疗。此外患者日常需要规律作息、做好防寒保暖工作、日常饮食多吃清淡稀软的食物、勤通风和多喝热水。<|im_end|>
# [INFO:swift] Dataset Token Length: 199.928377±80.550711, min=57.000000, max=1022.000000, size=37181
# [INFO:swift] The TrainArguments will be saved in: /mnt/workspace/output/v3-20250928-095853/args.json
# /usr/local/lib/python3.11/site-packages/awq/__init__.py:21: DeprecationWarning:
# I have left this message as the final dev message to help you transition.
#
# Important Notice:
# - AutoAWQ is officially deprecated and will no longer be maintained.
# - The last tested configuration used Torch 2.6.0 and Transformers 4.51.3.
# - If future versions of Transformers break AutoAWQ compatibility, please report the issue to the Transformers project.
#
# Alternative:
# - AutoAWQ has been adopted by the vLLM Project: https://github.com/vllm-project/llm-compressor
#
# For further inquiries, feel free to reach out:
# - X: https://x.com/casper_hansen_
# - LinkedIn: https://www.linkedin.com/in/casper-hansen-804005170/
#
#   warnings.warn(_FINAL_DEV_MESSAGE, category=DeprecationWarning, stacklevel=1)
# [INFO:swift] lora_config: LoraConfig(task_type='CAUSAL_LM', peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path='/mnt/workspace/.cache/modelscope/models/Qwen/Qwen2___5-7B-Instruct', revision=None, inference_mode=False, r=8, target_modules={'gate_proj', 'q_proj', 'up_proj', 'down_proj', 'k_proj', 'v_proj', 'o_proj'}, exclude_modules=None, lora_alpha=32, lora_dropout=0.05, fan_in_fan_out=False, bias='none', use_rslora=False, modules_to_save=[], init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={}, megatron_config=None, megatron_core='megatron.core', trainable_token_indices=None, loftq_config={}, eva_config=None, corda_config=None, use_dora=False, use_qalora=False, qalora_group_size=16, layer_replication=None, runtime_config=LoraRuntimeConfig(ephemeral_gpu_offload=False), lora_bias=False, lora_dtype=None, lorap_lr_ratio=None, lorap_emb_lr=1e-06)
# [INFO:swift] model: PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen2ForCausalLM(
#       (model): Qwen2Model(
#         (embed_tokens): Embedding(152064, 3584)
#         (layers): ModuleList(
#           (0-27): 28 x Qwen2DecoderLayer(
#             (self_attn): Qwen2Attention(
#               (q_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3584, out_features=3584, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=3584, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3584, out_features=512, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3584, out_features=512, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3584, out_features=3584, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=3584, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): Qwen2MLP(
#               (gate_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3584, out_features=18944, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=18944, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3584, out_features=18944, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=18944, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=18944, out_features=3584, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=18944, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=3584, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#             (post_attention_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#           )
#         )
#         (norm): Qwen2RMSNorm((3584,), eps=1e-06)
#         (rotary_emb): Qwen2RotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=3584, out_features=152064, bias=False)
#     )
#   )
# )
# [INFO:swift] model_parameter_info: PeftModelForCausalLM: 7635.8016M Params (20.1851M Trainable [0.2643%]), 0.0001M Buffers.
# /usr/local/lib/python3.11/site-packages/swift/trainers/mixin.py:94: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(
# /usr/local/lib/python3.11/site-packages/deepspeed/ops/op_builder/builder.py:18: DeprecationWarning: The distutils.sysconfig module is deprecated, use sysconfig instead
#   import distutils.sysconfig
# [2025-09-28 10:01:49,283] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-09-28 10:01:50,519] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# [INFO:swift] use_reentrant: True
# [INFO:swift] The logging file will be saved in: /mnt/workspace/output/v3-20250928-095853/logging.jsonl
#
# Train:   0%|          | 0/2324 [00:00<?, ?it/s][INFO:swift] use_logits_to_keep: True
#
# Train:   0%|          | 1/2324 [00:05<3:37:30,  5.62s/it]
#
# {'loss': 3.08439994, 'token_acc': 0.45889571, 'grad_norm': 3.79227996, 'learning_rate': 8.5e-07, 'memory(GiB)': 15.72, 'train_speed(iter/s)': 0.167354, 'epoch': 0.0, 'global_step/max_steps': '1/2324', 'percentage': '0.04%', 'elapsed_time': '5s', 'remaining_time': '3h 39m 52s'}
#
# Train:   0%|          | 1/2324 [00:05<3:37:30,  5.62s/it]
# Train:   0%|          | 1/2324 [00:05<3:37:30,  5.62s/it]
# Train:   0%|          | 2/2324 [00:10<3:17:41,  5.11s/it]
# Train:   0%|          | 3/2324 [00:15<3:10:54,  4.93s/it]
# Train:   0%|          | 4/2324 [00:19<3:02:15,  4.71s/it]
# Train:   0%|          | 5/2324 [00:24<3:01:13,  4.69s/it]
#
# {'loss': 2.88195038, 'token_acc': 0.48661218, 'grad_norm': 3.20182085, 'learning_rate': 4.27e-06, 'memory(GiB)': 17.24, 'train_speed(iter/s)': 0.204289, 'epoch': 0.0, 'global_step/max_steps': '5/2324', 'percentage': '0.22%', 'elapsed_time': '24s', 'remaining_time': '3h 7m 3s'}
#
# Train:   0%|          | 5/2324 [00:24<3:01:13,  4.69s/it]
# Train:   0%|          | 5/2324 [00:24<3:01:13,  4.69s/it]
# Train:   0%|          | 6/2324 [00:29<3:03:42,  4.76s/it]
# Train:   0%|          | 7/2324 [00:33<3:04:09,  4.77s/it]
# Train:   0%|          | 8/2324 [00:38<3:01:09,  4.69s/it]
# Train:   0%|          | 9/2324 [00:43<3:01:38,  4.71s/it]
# Train:   0%|          | 10/2324 [00:47<2:58:59,  4.64s/it]
#
# {'loss': 2.93168297, 'token_acc': 0.47017129, 'grad_norm': 4.19086838, 'learning_rate': 8.55e-06, 'memory(GiB)': 17.24, 'train_speed(iter/s)': 0.208689, 'epoch': 0.0, 'global_step/max_steps': '10/2324', 'percentage': '0.43%', 'elapsed_time': '47s', 'remaining_time': '3h 3m 50s'}
#
# Train:   0%|          | 10/2324 [00:47<2:58:59,  4.64s/it]
# Train:   0%|          | 10/2324 [00:47<2:58:59,  4.64s/it]
# Train:   0%|          | 11/2324 [00:52<3:02:30,  4.73s/it]
# Train:   1%|          | 12/2324 [00:57<3:03:02,  4.75s/it]
# Train:   1%|          | 13/2324 [01:01<3:00:37,  4.69s/it]
# Train:   1%|          | 14/2324 [01:06<2:58:31,  4.64s/it]
# Train:   1%|          | 15/2324 [01:11<3:00:30,  4.69s/it]
#
# {'loss': 2.73857079, 'token_acc': 0.49729854, 'grad_norm': 2.42210841, 'learning_rate': 1.282e-05, 'memory(GiB)': 17.24, 'train_speed(iter/s)': 0.2097, 'epoch': 0.01, 'global_step/max_steps': '15/2324', 'percentage': '0.65%', 'elapsed_time': '1m 11s', 'remaining_time': '3h 2m 51s'}
#
# Train:   1%|          | 15/2324 [01:11<3:00:30,  4.69s/it]
# Train:   1%|          | 15/2324 [01:11<3:00:30,  4.69s/it]
# Train:   1%|          | 16/2324 [01:16<3:05:07,  4.81s/it]
# Train:   1%|          | 17/2324 [01:21<3:11:42,  4.99s/it]
# Train:   1%|          | 18/2324 [01:26<3:09:31,  4.93s/it]
# Train:   1%|          | 19/2324 [01:31<3:10:42,  4.96s/it]
# Train:   1%|          | 20/2324 [01:36<3:06:21,  4.85s/it]
#
# {'loss': 2.60013561, 'token_acc': 0.51223354, 'grad_norm': 3.00279951, 'learning_rate': 1.709e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.207352, 'epoch': 0.01, 'global_step/max_steps': '20/2324', 'percentage': '0.86%', 'elapsed_time': '1m 36s', 'remaining_time': '3h 4m 36s'}
#
# Train:   1%|          | 20/2324 [01:36<3:06:21,  4.85s/it]
# Train:   1%|          | 20/2324 [01:36<3:06:21,  4.85s/it]
# Train:   1%|          | 21/2324 [01:40<3:05:40,  4.84s/it]
# Train:   1%|          | 22/2324 [01:45<3:06:03,  4.85s/it]
# Train:   1%|          | 23/2324 [01:50<3:09:51,  4.95s/it]
# Train:   1%|          | 24/2324 [01:55<3:07:36,  4.89s/it]
# Train:   1%|          | 25/2324 [02:00<3:04:28,  4.81s/it]
#
# {'loss': 2.35582924, 'token_acc': 0.53192426, 'grad_norm': 1.3073343, 'learning_rate': 2.137e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.207107, 'epoch': 0.01, 'global_step/max_steps': '25/2324', 'percentage': '1.08%', 'elapsed_time': '2m 0s', 'remaining_time': '3h 4m 32s'}
#
# Train:   1%|          | 25/2324 [02:00<3:04:28,  4.81s/it]
# Train:   1%|          | 25/2324 [02:00<3:04:28,  4.81s/it]
# Train:   1%|          | 26/2324 [02:05<3:03:54,  4.80s/it]
# Train:   1%|          | 27/2324 [02:10<3:07:01,  4.89s/it]
# Train:   1%|          | 28/2324 [02:14<3:04:15,  4.82s/it]
# Train:   1%|          | 29/2324 [02:19<3:07:42,  4.91s/it]
# Train:   1%|▏         | 30/2324 [02:24<3:02:41,  4.78s/it]
#
# {'loss': 2.15882778, 'token_acc': 0.56367821, 'grad_norm': 1.06233203, 'learning_rate': 2.564e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.207162, 'epoch': 0.01, 'global_step/max_steps': '30/2324', 'percentage': '1.29%', 'elapsed_time': '2m 24s', 'remaining_time': '3h 4m 13s'}
#
# Train:   1%|▏         | 30/2324 [02:24<3:02:41,  4.78s/it]
# Train:   1%|▏         | 30/2324 [02:24<3:02:41,  4.78s/it]
# Train:   1%|▏         | 31/2324 [02:29<3:04:44,  4.83s/it]
# Train:   1%|▏         | 32/2324 [02:34<3:03:24,  4.80s/it]
# Train:   1%|▏         | 33/2324 [02:38<3:01:45,  4.76s/it]
# Train:   1%|▏         | 34/2324 [02:43<3:01:05,  4.74s/it]
# Train:   2%|▏         | 35/2324 [02:48<3:00:01,  4.72s/it]
#
# {'loss': 2.29009342, 'token_acc': 0.54382403, 'grad_norm': 1.01155996, 'learning_rate': 2.991e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.207672, 'epoch': 0.02, 'global_step/max_steps': '35/2324', 'percentage': '1.51%', 'elapsed_time': '2m 48s', 'remaining_time': '3h 3m 22s'}
#
# Train:   2%|▏         | 35/2324 [02:48<3:00:01,  4.72s/it]
# Train:   2%|▏         | 35/2324 [02:48<3:00:01,  4.72s/it]
# Train:   2%|▏         | 36/2324 [02:52<3:00:34,  4.74s/it]
# Train:   2%|▏         | 37/2324 [02:57<3:00:15,  4.73s/it]
# Train:   2%|▏         | 38/2324 [03:02<2:59:48,  4.72s/it]
# Train:   2%|▏         | 39/2324 [03:07<2:59:46,  4.72s/it]
# Train:   2%|▏         | 40/2324 [03:11<3:00:50,  4.75s/it]
#
# {'loss': 2.30286465, 'token_acc': 0.51712694, 'grad_norm': 0.88036209, 'learning_rate': 3.419e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.208047, 'epoch': 0.02, 'global_step/max_steps': '40/2324', 'percentage': '1.72%', 'elapsed_time': '3m 12s', 'remaining_time': '3h 2m 44s'}
#
# Train:   2%|▏         | 40/2324 [03:12<3:00:50,  4.75s/it]
# Train:   2%|▏         | 40/2324 [03:12<3:00:50,  4.75s/it]
# Train:   2%|▏         | 41/2324 [03:16<2:59:38,  4.72s/it]
# Train:   2%|▏         | 42/2324 [03:21<3:02:36,  4.80s/it]
# Train:   2%|▏         | 43/2324 [03:26<2:59:03,  4.71s/it]
# Train:   2%|▏         | 44/2324 [03:31<3:02:04,  4.79s/it]
# Train:   2%|▏         | 45/2324 [03:35<3:00:24,  4.75s/it]
#
# {'loss': 2.26112251, 'token_acc': 0.52889281, 'grad_norm': 1.11696243, 'learning_rate': 3.846e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.208299, 'epoch': 0.02, 'global_step/max_steps': '45/2324', 'percentage': '1.94%', 'elapsed_time': '3m 35s', 'remaining_time': '3h 2m 7s'}
#
# Train:   2%|▏         | 45/2324 [03:35<3:00:24,  4.75s/it]
# Train:   2%|▏         | 45/2324 [03:35<3:00:24,  4.75s/it]
# Train:   2%|▏         | 46/2324 [03:40<3:03:22,  4.83s/it]
# Train:   2%|▏         | 47/2324 [03:44<2:56:57,  4.66s/it]
# Train:   2%|▏         | 48/2324 [03:49<2:50:57,  4.51s/it]
# Train:   2%|▏         | 49/2324 [03:53<2:50:20,  4.49s/it]
# Train:   2%|▏         | 50/2324 [03:58<2:51:54,  4.54s/it]
#
# {'loss': 2.28810654, 'token_acc': 0.5158505, 'grad_norm': 0.78381974, 'learning_rate': 4.274e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209587, 'epoch': 0.02, 'global_step/max_steps': '50/2324', 'percentage': '2.15%', 'elapsed_time': '3m 58s', 'remaining_time': '3h 0m 36s'}
#
# Train:   2%|▏         | 50/2324 [03:58<2:51:54,  4.54s/it]
# Train:   2%|▏         | 50/2324 [03:58<2:51:54,  4.54s/it][INFO:swift] Saving model checkpoint to /mnt/workspace/output/v3-20250928-095853/checkpoint-50
#
# Train:   2%|▏         | 51/2324 [04:04<3:06:37,  4.93s/it]
# Train:   2%|▏         | 52/2324 [04:08<2:58:45,  4.72s/it]
# Train:   2%|▏         | 53/2324 [04:13<3:01:43,  4.80s/it]
# Train:   2%|▏         | 54/2324 [04:18<3:01:00,  4.78s/it]
# Train:   2%|▏         | 55/2324 [04:22<2:59:34,  4.75s/it]
#
# {'loss': 2.27709713, 'token_acc': 0.52847462, 'grad_norm': 0.88505256, 'learning_rate': 4.701e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209092, 'epoch': 0.02, 'global_step/max_steps': '55/2324', 'percentage': '2.37%', 'elapsed_time': '4m 22s', 'remaining_time': '3h 0m 44s'}
#
# Train:   2%|▏         | 55/2324 [04:22<2:59:34,  4.75s/it]
# Train:   2%|▏         | 55/2324 [04:22<2:59:34,  4.75s/it]
# Train:   2%|▏         | 56/2324 [04:27<2:58:44,  4.73s/it]
# Train:   2%|▏         | 57/2324 [04:31<2:54:37,  4.62s/it]
# Train:   2%|▏         | 58/2324 [04:36<2:58:14,  4.72s/it]
# Train:   3%|▎         | 59/2324 [04:41<2:56:22,  4.67s/it]
# Train:   3%|▎         | 60/2324 [04:46<2:59:14,  4.75s/it]
#
# {'loss': 2.01896515, 'token_acc': 0.57245402, 'grad_norm': 0.80991596, 'learning_rate': 5.128e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209396, 'epoch': 0.03, 'global_step/max_steps': '60/2324', 'percentage': '2.58%', 'elapsed_time': '4m 46s', 'remaining_time': '3h 0m 2s'}
#
# Train:   3%|▎         | 60/2324 [04:46<2:59:14,  4.75s/it]
# Train:   3%|▎         | 60/2324 [04:46<2:59:14,  4.75s/it]
# Train:   3%|▎         | 61/2324 [04:51<3:00:52,  4.80s/it]
# Train:   3%|▎         | 62/2324 [04:55<2:55:52,  4.67s/it]
# Train:   3%|▎         | 63/2324 [05:00<3:02:12,  4.84s/it]
# Train:   3%|▎         | 64/2324 [05:05<3:04:34,  4.90s/it]
# Train:   3%|▎         | 65/2324 [05:10<3:00:32,  4.80s/it]
#
# {'loss': 2.21512432, 'token_acc': 0.53775422, 'grad_norm': 0.87778515, 'learning_rate': 5.556e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209249, 'epoch': 0.03, 'global_step/max_steps': '65/2324', 'percentage': '2.80%', 'elapsed_time': '5m 10s', 'remaining_time': '2h 59m 45s'}
#
# Train:   3%|▎         | 65/2324 [05:10<3:00:32,  4.80s/it]
# Train:   3%|▎         | 65/2324 [05:10<3:00:32,  4.80s/it]
# Train:   3%|▎         | 66/2324 [05:14<2:59:29,  4.77s/it]
# Train:   3%|▎         | 67/2324 [05:19<3:01:29,  4.82s/it]
# Train:   3%|▎         | 68/2324 [05:24<3:02:01,  4.84s/it]
# Train:   3%|▎         | 69/2324 [05:29<2:59:16,  4.77s/it]
# Train:   3%|▎         | 70/2324 [05:34<2:59:04,  4.77s/it]
#
# {'loss': 2.33298683, 'token_acc': 0.51665303, 'grad_norm': 0.8858335, 'learning_rate': 5.983e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209242, 'epoch': 0.03, 'global_step/max_steps': '70/2324', 'percentage': '3.01%', 'elapsed_time': '5m 34s', 'remaining_time': '2h 59m 22s'}
#
# Train:   3%|▎         | 70/2324 [05:34<2:59:04,  4.77s/it]
# Train:   3%|▎         | 70/2324 [05:34<2:59:04,  4.77s/it]
# Train:   3%|▎         | 71/2324 [05:38<2:58:42,  4.76s/it]
# Train:   3%|▎         | 72/2324 [05:43<2:55:05,  4.67s/it]
# Train:   3%|▎         | 73/2324 [05:48<3:00:44,  4.82s/it]
# Train:   3%|▎         | 74/2324 [05:53<2:56:48,  4.71s/it]
# Train:   3%|▎         | 75/2324 [05:57<2:53:04,  4.62s/it]
#
# {'loss': 2.09275208, 'token_acc': 0.5658083, 'grad_norm': 0.99755532, 'learning_rate': 6.41e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209634, 'epoch': 0.03, 'global_step/max_steps': '75/2324', 'percentage': '3.23%', 'elapsed_time': '5m 57s', 'remaining_time': '2h 58m 38s'}
#
# Train:   3%|▎         | 75/2324 [05:57<2:53:04,  4.62s/it]
# Train:   3%|▎         | 75/2324 [05:57<2:53:04,  4.62s/it]
# Train:   3%|▎         | 76/2324 [06:02<2:53:45,  4.64s/it]
# Train:   3%|▎         | 77/2324 [06:06<2:52:03,  4.59s/it]
# Train:   3%|▎         | 78/2324 [06:11<2:55:42,  4.69s/it]
# Train:   3%|▎         | 79/2324 [06:16<2:55:29,  4.69s/it]
# Train:   3%|▎         | 80/2324 [06:21<2:58:13,  4.77s/it]
#
# {'loss': 2.29264469, 'token_acc': 0.52208275, 'grad_norm': 0.75402158, 'learning_rate': 6.838e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209702, 'epoch': 0.03, 'global_step/max_steps': '80/2324', 'percentage': '3.44%', 'elapsed_time': '6m 21s', 'remaining_time': '2h 58m 11s'}
#
# Train:   3%|▎         | 80/2324 [06:21<2:58:13,  4.77s/it]
# Train:   3%|▎         | 80/2324 [06:21<2:58:13,  4.77s/it]
# Train:   3%|▎         | 81/2324 [06:25<2:55:15,  4.69s/it]
# Train:   4%|▎         | 82/2324 [06:30<2:53:03,  4.63s/it]
# Train:   4%|▎         | 83/2324 [06:34<2:51:00,  4.58s/it]
# Train:   4%|▎         | 84/2324 [06:39<2:50:29,  4.57s/it]
# Train:   4%|▎         | 85/2324 [06:44<2:55:47,  4.71s/it]
#
# {'loss': 2.1027216, 'token_acc': 0.55461493, 'grad_norm': 0.76214886, 'learning_rate': 7.265e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.210115, 'epoch': 0.04, 'global_step/max_steps': '85/2324', 'percentage': '3.66%', 'elapsed_time': '6m 44s', 'remaining_time': '2h 57m 28s'}
#
# Train:   4%|▎         | 85/2324 [06:44<2:55:47,  4.71s/it]
# Train:   4%|▎         | 85/2324 [06:44<2:55:47,  4.71s/it]
# Train:   4%|▎         | 86/2324 [06:48<2:55:10,  4.70s/it]
# Train:   4%|▎         | 87/2324 [06:53<2:51:53,  4.61s/it]
# Train:   4%|▍         | 88/2324 [06:58<2:58:37,  4.79s/it]
# Train:   4%|▍         | 89/2324 [07:03<2:56:57,  4.75s/it]
# Train:   4%|▍         | 90/2324 [07:07<2:57:40,  4.77s/it]
#
# {'loss': 2.21973896, 'token_acc': 0.52999889, 'grad_norm': 0.86332852, 'learning_rate': 7.692e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.21013, 'epoch': 0.04, 'global_step/max_steps': '90/2324', 'percentage': '3.87%', 'elapsed_time': '7m 8s', 'remaining_time': '2h 57m 3s'}
#
# Train:   4%|▍         | 90/2324 [07:08<2:57:40,  4.77s/it]
# Train:   4%|▍         | 90/2324 [07:08<2:57:40,  4.77s/it]
# Train:   4%|▍         | 91/2324 [07:12<2:54:55,  4.70s/it]
# Train:   4%|▍         | 92/2324 [07:17<2:57:30,  4.77s/it]
# Train:   4%|▍         | 93/2324 [07:22<2:59:27,  4.83s/it]
# Train:   4%|▍         | 94/2324 [07:26<2:54:34,  4.70s/it]
# Train:   4%|▍         | 95/2324 [07:31<2:58:32,  4.81s/it]
#
# {'loss': 2.2014637, 'token_acc': 0.53104225, 'grad_norm': 0.80431908, 'learning_rate': 8.12e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.21009, 'epoch': 0.04, 'global_step/max_steps': '95/2324', 'percentage': '4.09%', 'elapsed_time': '7m 31s', 'remaining_time': '2h 56m 43s'}
#
# Train:   4%|▍         | 95/2324 [07:31<2:58:32,  4.81s/it]
# Train:   4%|▍         | 95/2324 [07:31<2:58:32,  4.81s/it]
# Train:   4%|▍         | 96/2324 [07:36<2:59:49,  4.84s/it]
# Train:   4%|▍         | 97/2324 [07:41<2:58:25,  4.81s/it]
# Train:   4%|▍         | 98/2324 [07:46<2:58:40,  4.82s/it]
# Train:   4%|▍         | 99/2324 [07:51<2:57:07,  4.78s/it]
# Train:   4%|▍         | 100/2324 [07:55<2:57:39,  4.79s/it]
#
# {'loss': 2.18770962, 'token_acc': 0.54214147, 'grad_norm': 0.74992484, 'learning_rate': 8.547e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209999, 'epoch': 0.04, 'global_step/max_steps': '100/2324', 'percentage': '4.30%', 'elapsed_time': '7m 55s', 'remaining_time': '2h 56m 23s'}
#
# Train:   4%|▍         | 100/2324 [07:55<2:57:39,  4.79s/it]
# Train:   4%|▍         | 100/2324 [07:55<2:57:39,  4.79s/it][INFO:swift] Saving model checkpoint to /mnt/workspace/output/v3-20250928-095853/checkpoint-100
#
# Train:   4%|▍         | 101/2324 [08:01<3:10:38,  5.15s/it]
# Train:   4%|▍         | 102/2324 [08:06<3:06:38,  5.04s/it]
# Train:   4%|▍         | 103/2324 [08:11<3:04:02,  4.97s/it]
# Train:   4%|▍         | 104/2324 [08:16<3:01:08,  4.90s/it]
# Train:   5%|▍         | 105/2324 [08:20<2:56:34,  4.77s/it]
#
# {'loss': 2.13647537, 'token_acc': 0.54361302, 'grad_norm': 0.89538789, 'learning_rate': 8.974e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209591, 'epoch': 0.05, 'global_step/max_steps': '105/2324', 'percentage': '4.52%', 'elapsed_time': '8m 20s', 'remaining_time': '2h 56m 21s'}
#
# Train:   5%|▍         | 105/2324 [08:20<2:56:34,  4.77s/it]
# Train:   5%|▍         | 105/2324 [08:20<2:56:34,  4.77s/it]
# Train:   5%|▍         | 106/2324 [08:25<2:59:00,  4.84s/it]
# Train:   5%|▍         | 107/2324 [08:30<2:55:51,  4.76s/it]
# Train:   5%|▍         | 108/2324 [08:35<2:56:31,  4.78s/it]
# Train:   5%|▍         | 109/2324 [08:39<2:57:47,  4.82s/it]
# Train:   5%|▍         | 110/2324 [08:45<3:03:10,  4.96s/it]
#
# {'loss': 2.28033123, 'token_acc': 0.51725576, 'grad_norm': 0.94973528, 'learning_rate': 9.402e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209293, 'epoch': 0.05, 'global_step/max_steps': '110/2324', 'percentage': '4.73%', 'elapsed_time': '8m 45s', 'remaining_time': '2h 56m 12s'}
#
# Train:   5%|▍         | 110/2324 [08:45<3:03:10,  4.96s/it]
# Train:   5%|▍         | 110/2324 [08:45<3:03:10,  4.96s/it]
# Train:   5%|▍         | 111/2324 [08:49<3:00:13,  4.89s/it]
# Train:   5%|▍         | 112/2324 [08:54<2:55:43,  4.77s/it]
# Train:   5%|▍         | 113/2324 [08:58<2:51:01,  4.64s/it]
# Train:   5%|▍         | 114/2324 [09:03<2:55:13,  4.76s/it]
# Train:   5%|▍         | 115/2324 [09:08<2:51:15,  4.65s/it]
#
# {'loss': 2.3320507, 'token_acc': 0.51750683, 'grad_norm': 1.1123333, 'learning_rate': 9.829e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209642, 'epoch': 0.05, 'global_step/max_steps': '115/2324', 'percentage': '4.95%', 'elapsed_time': '9m 8s', 'remaining_time': '2h 55m 31s'}
#
# Train:   5%|▍         | 115/2324 [09:08<2:51:15,  4.65s/it]
# Train:   5%|▍         | 115/2324 [09:08<2:51:15,  4.65s/it]
# Train:   5%|▍         | 116/2324 [09:13<2:52:57,  4.70s/it]
# Train:   5%|▌         | 117/2324 [09:17<2:52:03,  4.68s/it]
# Train:   5%|▌         | 118/2324 [09:22<2:48:48,  4.59s/it]
# Train:   5%|▌         | 119/2324 [09:26<2:50:42,  4.64s/it]
# Train:   5%|▌         | 120/2324 [09:31<2:54:39,  4.75s/it]
#
# {'loss': 2.09163246, 'token_acc': 0.55400198, 'grad_norm': 0.72958004, 'learning_rate': 0.0001, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.20973, 'epoch': 0.05, 'global_step/max_steps': '120/2324', 'percentage': '5.16%', 'elapsed_time': '9m 31s', 'remaining_time': '2h 55m 3s'}
#
# Train:   5%|▌         | 120/2324 [09:31<2:54:39,  4.75s/it]
# Train:   5%|▌         | 120/2324 [09:31<2:54:39,  4.75s/it]
# Train:   5%|▌         | 121/2324 [09:36<2:55:09,  4.77s/it]
# Train:   5%|▌         | 122/2324 [09:41<2:53:35,  4.73s/it]
# Train:   5%|▌         | 123/2324 [09:46<2:56:06,  4.80s/it]
# Train:   5%|▌         | 124/2324 [09:50<2:49:31,  4.62s/it]
# Train:   5%|▌         | 125/2324 [09:55<2:50:38,  4.66s/it]
#
# {'loss': 2.26271133, 'token_acc': 0.52086379, 'grad_norm': 0.99844664, 'learning_rate': 0.0001, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209903, 'epoch': 0.05, 'global_step/max_steps': '125/2324', 'percentage': '5.38%', 'elapsed_time': '9m 55s', 'remaining_time': '2h 54m 30s'}
#
# Train:   5%|▌         | 125/2324 [09:55<2:50:38,  4.66s/it]
# Train:   5%|▌         | 125/2324 [09:55<2:50:38,  4.66s/it]
# Train:   5%|▌         | 126/2324 [10:00<2:54:50,  4.77s/it]
# Train:   5%|▌         | 127/2324 [10:04<2:51:32,  4.68s/it]
# Train:   6%|▌         | 128/2324 [10:09<2:55:38,  4.80s/it]
# Train:   6%|▌         | 129/2324 [10:14<2:53:33,  4.74s/it]
# Train:   6%|▌         | 130/2324 [10:18<2:50:06,  4.65s/it]
#
# {'loss': 2.26851521, 'token_acc': 0.52242958, 'grad_norm': 1.15128171, 'learning_rate': 9.999e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209963, 'epoch': 0.06, 'global_step/max_steps': '130/2324', 'percentage': '5.59%', 'elapsed_time': '10m 18s', 'remaining_time': '2h 54m 4s'}
#
# Train:   6%|▌         | 130/2324 [10:18<2:50:06,  4.65s/it]
# Train:   6%|▌         | 130/2324 [10:18<2:50:06,  4.65s/it]
# Train:   6%|▌         | 131/2324 [10:23<2:52:18,  4.71s/it]
# Train:   6%|▌         | 132/2324 [10:28<2:50:02,  4.65s/it]
# Train:   6%|▌         | 133/2324 [10:32<2:48:33,  4.62s/it]
# Train:   6%|▌         | 134/2324 [10:37<2:47:15,  4.58s/it]
# Train:   6%|▌         | 135/2324 [10:42<2:51:26,  4.70s/it]
#
# {'loss': 2.13009834, 'token_acc': 0.54612074, 'grad_norm': 0.79882151, 'learning_rate': 9.998e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.210106, 'epoch': 0.06, 'global_step/max_steps': '135/2324', 'percentage': '5.81%', 'elapsed_time': '10m 42s', 'remaining_time': '2h 53m 33s'}
#
# Train:   6%|▌         | 135/2324 [10:42<2:51:26,  4.70s/it]
# Train:   6%|▌         | 135/2324 [10:42<2:51:26,  4.70s/it]
# Train:   6%|▌         | 136/2324 [10:47<2:58:26,  4.89s/it]
# Train:   6%|▌         | 137/2324 [10:52<2:54:03,  4.78s/it]
# Train:   6%|▌         | 138/2324 [10:57<2:57:39,  4.88s/it]
# Train:   6%|▌         | 139/2324 [11:02<2:59:49,  4.94s/it]
# Train:   6%|▌         | 140/2324 [11:06<2:54:39,  4.80s/it]
#
# {'loss': 2.19815559, 'token_acc': 0.52872494, 'grad_norm': 1.25415456, 'learning_rate': 9.997e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209881, 'epoch': 0.06, 'global_step/max_steps': '140/2324', 'percentage': '6.02%', 'elapsed_time': '11m 6s', 'remaining_time': '2h 53m 21s'}
#
# Train:   6%|▌         | 140/2324 [11:06<2:54:39,  4.80s/it]
# Train:   6%|▌         | 140/2324 [11:06<2:54:39,  4.80s/it]
# Train:   6%|▌         | 141/2324 [11:11<2:53:43,  4.77s/it]
# Train:   6%|▌         | 142/2324 [11:16<2:56:48,  4.86s/it]
# Train:   6%|▌         | 143/2324 [11:21<2:56:30,  4.86s/it]
# Train:   6%|▌         | 144/2324 [11:26<2:55:51,  4.84s/it]
# Train:   6%|▌         | 145/2324 [11:30<2:53:32,  4.78s/it]
#
# {'loss': 2.02486591, 'token_acc': 0.56428181, 'grad_norm': 0.97833532, 'learning_rate': 9.996e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209808, 'epoch': 0.06, 'global_step/max_steps': '145/2324', 'percentage': '6.24%', 'elapsed_time': '11m 30s', 'remaining_time': '2h 53m 1s'}
#
# Train:   6%|▌         | 145/2324 [11:30<2:53:32,  4.78s/it]
# Train:   6%|▌         | 145/2324 [11:30<2:53:32,  4.78s/it]
# Train:   6%|▋         | 146/2324 [11:35<2:52:41,  4.76s/it]
# Train:   6%|▋         | 147/2324 [11:40<2:55:41,  4.84s/it]
# Train:   6%|▋         | 148/2324 [11:45<2:55:00,  4.83s/it]
# Train:   6%|▋         | 149/2324 [11:50<2:58:10,  4.92s/it]
# Train:   6%|▋         | 150/2324 [11:55<2:57:25,  4.90s/it]
#
# {'loss': 2.18238277, 'token_acc': 0.53568147, 'grad_norm': 0.93628567, 'learning_rate': 9.994e-05, 'memory(GiB)': 18.81, 'train_speed(iter/s)': 0.209608, 'epoch': 0.06, 'global_step/max_steps': '150/2324', 'percentage': '6.45%', 'elapsed_time': '11m 55s', 'remaining_time': '2h 52m 47s'}
#
# Train:   6%|▋         | 150/2324 [11:55<2:57:25,  4.90s/it]
# Train:   6%|▋         | 150/2324 [11:55<2:57:25,  4.90s/it][INFO:swift] Saving model checkpoint to /mnt/workspace/output/v3-20250928-095853/checkpoint-150
#
# Train:   6%|▋         | 151/2324 [12:01<3:06:28,  5.15s/it]
# Train:   7%|▋         | 152/2324 [12:05<3:04:22,  5.09s/it]
# ...
# Train:  96%|█████████▌| 2227/2324 [2:59:02<07:43,  4.77s/it]
# Train:  96%|█████████▌| 2228/2324 [2:59:07<07:48,  4.88s/it]
# Train:  96%|█████████▌| 2229/2324 [2:59:12<07:41,  4.85s/it]
# Train:  96%|█████████▌| 2230/2324 [2:59:16<07:26,  4.75s/it]
#
# {'loss': 1.89471817, 'token_acc': 0.59634683, 'grad_norm': 1.63654029, 'learning_rate': 4.5e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207308, 'epoch': 0.96, 'global_step/max_steps': '2230/2324', 'percentage': '95.96%', 'elapsed_time': '2h 59m 16s', 'remaining_time': '7m 33s'}
#
# Train:  96%|█████████▌| 2230/2324 [2:59:16<07:26,  4.75s/it]
# Train:  96%|█████████▌| 2230/2324 [2:59:16<07:26,  4.75s/it]
# Train:  96%|█████████▌| 2231/2324 [2:59:21<07:25,  4.79s/it]
# Train:  96%|█████████▌| 2232/2324 [2:59:26<07:17,  4.76s/it]
# Train:  96%|█████████▌| 2233/2324 [2:59:31<07:20,  4.84s/it]
# Train:  96%|█████████▌| 2234/2324 [2:59:35<07:03,  4.71s/it]
# Train:  96%|█████████▌| 2235/2324 [2:59:40<07:03,  4.76s/it]
#
# {'loss': 1.82506771, 'token_acc': 0.59975153, 'grad_norm': 1.6582644, 'learning_rate': 4e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207313, 'epoch': 0.96, 'global_step/max_steps': '2235/2324', 'percentage': '96.17%', 'elapsed_time': '2h 59m 40s', 'remaining_time': '7m 9s'}
#
# Train:  96%|█████████▌| 2235/2324 [2:59:40<07:03,  4.76s/it]
# Train:  96%|█████████▌| 2235/2324 [2:59:40<07:03,  4.76s/it]
# Train:  96%|█████████▌| 2236/2324 [2:59:45<06:54,  4.71s/it]
# Train:  96%|█████████▋| 2237/2324 [2:59:49<06:48,  4.69s/it]
# Train:  96%|█████████▋| 2238/2324 [2:59:54<06:53,  4.81s/it]
# Train:  96%|█████████▋| 2239/2324 [2:59:59<06:37,  4.68s/it]
# Train:  96%|█████████▋| 2240/2324 [3:00:03<06:27,  4.61s/it]
#
# {'loss': 1.80112629, 'token_acc': 0.6181513, 'grad_norm': 1.92385674, 'learning_rate': 3.6e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207332, 'epoch': 0.96, 'global_step/max_steps': '2240/2324', 'percentage': '96.39%', 'elapsed_time': '3h 0m 3s', 'remaining_time': '6m 45s'}
#
# Train:  96%|█████████▋| 2240/2324 [3:00:03<06:27,  4.61s/it]
# Train:  96%|█████████▋| 2240/2324 [3:00:03<06:27,  4.61s/it]
# Train:  96%|█████████▋| 2241/2324 [3:00:08<06:25,  4.65s/it]
# Train:  96%|█████████▋| 2242/2324 [3:00:12<06:16,  4.59s/it]
# Train:  97%|█████████▋| 2243/2324 [3:00:17<06:12,  4.59s/it]
# Train:  97%|█████████▋| 2244/2324 [3:00:22<06:15,  4.69s/it]
# Train:  97%|█████████▋| 2245/2324 [3:00:27<06:17,  4.78s/it]
#
# {'loss': 2.03143425, 'token_acc': 0.57159515, 'grad_norm': 1.29025817, 'learning_rate': 3.2e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.20734, 'epoch': 0.97, 'global_step/max_steps': '2245/2324', 'percentage': '96.60%', 'elapsed_time': '3h 0m 27s', 'remaining_time': '6m 21s'}
#
# Train:  97%|█████████▋| 2245/2324 [3:00:27<06:17,  4.78s/it]
# Train:  97%|█████████▋| 2245/2324 [3:00:27<06:17,  4.78s/it]
# Train:  97%|█████████▋| 2246/2324 [3:00:31<06:08,  4.72s/it]
# Train:  97%|█████████▋| 2247/2324 [3:00:36<06:02,  4.71s/it]
# Train:  97%|█████████▋| 2248/2324 [3:00:41<05:55,  4.67s/it]
# Train:  97%|█████████▋| 2249/2324 [3:00:46<06:03,  4.85s/it]
# Train:  97%|█████████▋| 2250/2324 [3:00:50<05:52,  4.76s/it]
#
# {'loss': 1.7516304, 'token_acc': 0.62234811, 'grad_norm': 1.68894291, 'learning_rate': 2.8e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207348, 'epoch': 0.97, 'global_step/max_steps': '2250/2324', 'percentage': '96.82%', 'elapsed_time': '3h 0m 50s', 'remaining_time': '5m 56s'}
#
# Train:  97%|█████████▋| 2250/2324 [3:00:51<05:52,  4.76s/it]
# Train:  97%|█████████▋| 2250/2324 [3:00:51<05:52,  4.76s/it][INFO:swift] Saving model checkpoint to /mnt/workspace/output/v3-20250928-095853/checkpoint-2250
#
# Train:  97%|█████████▋| 2251/2324 [3:00:56<06:13,  5.12s/it]
# Train:  97%|█████████▋| 2252/2324 [3:01:02<06:13,  5.18s/it]
# Train:  97%|█████████▋| 2253/2324 [3:01:06<05:50,  4.93s/it]
# Train:  97%|█████████▋| 2254/2324 [3:01:11<05:43,  4.91s/it]
# Train:  97%|█████████▋| 2255/2324 [3:01:16<05:32,  4.82s/it]
#
# {'loss': 1.76714687, 'token_acc': 0.62833745, 'grad_norm': 1.855353, 'learning_rate': 2.4e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.20733, 'epoch': 0.97, 'global_step/max_steps': '2255/2324', 'percentage': '97.03%', 'elapsed_time': '3h 1m 16s', 'remaining_time': '5m 32s'}
#
# Train:  97%|█████████▋| 2255/2324 [3:01:16<05:32,  4.82s/it]
# Train:  97%|█████████▋| 2255/2324 [3:01:16<05:32,  4.82s/it]
# Train:  97%|█████████▋| 2256/2324 [3:01:20<05:23,  4.76s/it]
# Train:  97%|█████████▋| 2257/2324 [3:01:25<05:22,  4.81s/it]
# Train:  97%|█████████▋| 2258/2324 [3:01:29<05:09,  4.68s/it]
# Train:  97%|█████████▋| 2259/2324 [3:01:34<05:10,  4.78s/it]
# Train:  97%|█████████▋| 2260/2324 [3:01:39<05:00,  4.70s/it]
#
# {'loss': 1.79396114, 'token_acc': 0.61162949, 'grad_norm': 1.7494607, 'learning_rate': 2.1e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207342, 'epoch': 0.97, 'global_step/max_steps': '2260/2324', 'percentage': '97.25%', 'elapsed_time': '3h 1m 39s', 'remaining_time': '5m 8s'}
#
# Train:  97%|█████████▋| 2260/2324 [3:01:39<05:00,  4.70s/it]
# Train:  97%|█████████▋| 2260/2324 [3:01:39<05:00,  4.70s/it]
# Train:  97%|█████████▋| 2261/2324 [3:01:43<04:49,  4.60s/it]
# Train:  97%|█████████▋| 2262/2324 [3:01:49<04:55,  4.77s/it]
# Train:  97%|█████████▋| 2263/2324 [3:01:53<04:46,  4.70s/it]
# Train:  97%|█████████▋| 2264/2324 [3:01:58<04:43,  4.72s/it]
# Train:  97%|█████████▋| 2265/2324 [3:02:03<04:41,  4.77s/it]
#
# {'loss': 1.82883205, 'token_acc': 0.59912603, 'grad_norm': 1.25024891, 'learning_rate': 1.8e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207349, 'epoch': 0.97, 'global_step/max_steps': '2265/2324', 'percentage': '97.46%', 'elapsed_time': '3h 2m 3s', 'remaining_time': '4m 44s'}
#
# Train:  97%|█████████▋| 2265/2324 [3:02:03<04:41,  4.77s/it]
# Train:  97%|█████████▋| 2265/2324 [3:02:03<04:41,  4.77s/it]
# Train:  98%|█████████▊| 2266/2324 [3:02:08<04:45,  4.92s/it]
# Train:  98%|█████████▊| 2267/2324 [3:02:13<04:44,  4.99s/it]
# Train:  98%|█████████▊| 2268/2324 [3:02:18<04:32,  4.86s/it]
# Train:  98%|█████████▊| 2269/2324 [3:02:22<04:20,  4.74s/it]
# Train:  98%|█████████▊| 2270/2324 [3:02:27<04:19,  4.81s/it]
#
# {'loss': 1.84618759, 'token_acc': 0.59737888, 'grad_norm': 1.88048124, 'learning_rate': 1.5e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207344, 'epoch': 0.98, 'global_step/max_steps': '2270/2324', 'percentage': '97.68%', 'elapsed_time': '3h 2m 27s', 'remaining_time': '4m 20s'}
#
# Train:  98%|█████████▊| 2270/2324 [3:02:27<04:19,  4.81s/it]
# Train:  98%|█████████▊| 2270/2324 [3:02:27<04:19,  4.81s/it]
# Train:  98%|█████████▊| 2271/2324 [3:02:32<04:18,  4.89s/it]
# Train:  98%|█████████▊| 2272/2324 [3:02:37<04:12,  4.86s/it]
# Train:  98%|█████████▊| 2273/2324 [3:02:42<04:07,  4.85s/it]
# Train:  98%|█████████▊| 2274/2324 [3:02:47<03:59,  4.80s/it]
# Train:  98%|█████████▊| 2275/2324 [3:02:51<03:52,  4.75s/it]
#
# {'loss': 1.97249832, 'token_acc': 0.57134974, 'grad_norm': 1.53652334, 'learning_rate': 1.2e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207346, 'epoch': 0.98, 'global_step/max_steps': '2275/2324', 'percentage': '97.89%', 'elapsed_time': '3h 2m 51s', 'remaining_time': '3m 56s'}
#
# Train:  98%|█████████▊| 2275/2324 [3:02:51<03:52,  4.75s/it]
# Train:  98%|█████████▊| 2275/2324 [3:02:51<03:52,  4.75s/it]
# Train:  98%|█████████▊| 2276/2324 [3:02:56<03:43,  4.66s/it]
# Train:  98%|█████████▊| 2277/2324 [3:03:00<03:39,  4.67s/it]
# Train:  98%|█████████▊| 2278/2324 [3:03:06<03:45,  4.90s/it]
# Train:  98%|█████████▊| 2279/2324 [3:03:11<03:40,  4.91s/it]
# Train:  98%|█████████▊| 2280/2324 [3:03:16<03:47,  5.16s/it]
#
# {'loss': 1.89017887, 'token_acc': 0.59599584, 'grad_norm': 1.13527191, 'learning_rate': 1e-07, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207324, 'epoch': 0.98, 'global_step/max_steps': '2280/2324', 'percentage': '98.11%', 'elapsed_time': '3h 3m 16s', 'remaining_time': '3m 32s'}
#
# Train:  98%|█████████▊| 2280/2324 [3:03:17<03:47,  5.16s/it]
# Train:  98%|█████████▊| 2280/2324 [3:03:17<03:47,  5.16s/it]
# Train:  98%|█████████▊| 2281/2324 [3:03:21<03:40,  5.13s/it]
# Train:  98%|█████████▊| 2282/2324 [3:03:26<03:23,  4.84s/it]
# Train:  98%|█████████▊| 2283/2324 [3:03:30<03:15,  4.77s/it]
# Train:  98%|█████████▊| 2284/2324 [3:03:36<03:21,  5.05s/it]
# Train:  98%|█████████▊| 2285/2324 [3:03:40<03:09,  4.87s/it]
#
# {'loss': 1.76475677, 'token_acc': 0.61089212, 'grad_norm': 1.71667397, 'learning_rate': 8e-08, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207327, 'epoch': 0.98, 'global_step/max_steps': '2285/2324', 'percentage': '98.32%', 'elapsed_time': '3h 3m 40s', 'remaining_time': '3m 8s'}
#
# Train:  98%|█████████▊| 2285/2324 [3:03:40<03:09,  4.87s/it]
# Train:  98%|█████████▊| 2285/2324 [3:03:40<03:09,  4.87s/it]
# Train:  98%|█████████▊| 2286/2324 [3:03:46<03:09,  4.98s/it]
# Train:  98%|█████████▊| 2287/2324 [3:03:50<02:57,  4.79s/it]
# Train:  98%|█████████▊| 2288/2324 [3:03:55<02:53,  4.83s/it]
# Train:  98%|█████████▊| 2289/2324 [3:04:00<02:47,  4.77s/it]
# Train:  99%|█████████▊| 2290/2324 [3:04:04<02:38,  4.66s/it]
#
# {'loss': 1.99531174, 'token_acc': 0.56526687, 'grad_norm': 2.26075268, 'learning_rate': 6e-08, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207338, 'epoch': 0.99, 'global_step/max_steps': '2290/2324', 'percentage': '98.54%', 'elapsed_time': '3h 4m 4s', 'remaining_time': '2m 43s'}
#
# Train:  99%|█████████▊| 2290/2324 [3:04:04<02:38,  4.66s/it]
# Train:  99%|█████████▊| 2290/2324 [3:04:04<02:38,  4.66s/it]
# Train:  99%|█████████▊| 2291/2324 [3:04:09<02:33,  4.65s/it]
# Train:  99%|█████████▊| 2292/2324 [3:04:13<02:29,  4.68s/it]
# Train:  99%|█████████▊| 2293/2324 [3:04:18<02:24,  4.68s/it]
# Train:  99%|█████████▊| 2294/2324 [3:04:23<02:21,  4.72s/it]
# Train:  99%|█████████▉| 2295/2324 [3:04:28<02:20,  4.83s/it]
#
# {'loss': 1.70852528, 'token_acc': 0.63002566, 'grad_norm': 1.42936623, 'learning_rate': 4e-08, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207341, 'epoch': 0.99, 'global_step/max_steps': '2295/2324', 'percentage': '98.75%', 'elapsed_time': '3h 4m 28s', 'remaining_time': '2m 19s'}
#
# Train:  99%|█████████▉| 2295/2324 [3:04:28<02:20,  4.83s/it]
# Train:  99%|█████████▉| 2295/2324 [3:04:28<02:20,  4.83s/it]
# Train:  99%|█████████▉| 2296/2324 [3:04:33<02:17,  4.93s/it]
# Train:  99%|█████████▉| 2297/2324 [3:04:37<02:07,  4.73s/it]
# Train:  99%|█████████▉| 2298/2324 [3:04:42<02:05,  4.83s/it]
# Train:  99%|█████████▉| 2299/2324 [3:04:47<01:59,  4.77s/it]
# Train:  99%|█████████▉| 2300/2324 [3:04:53<02:00,  5.01s/it]
#
# {'loss': 1.91951237, 'token_acc': 0.58025884, 'grad_norm': 1.19797289, 'learning_rate': 3e-08, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.20733, 'epoch': 0.99, 'global_step/max_steps': '2300/2324', 'percentage': '98.97%', 'elapsed_time': '3h 4m 53s', 'remaining_time': '1m 55s'}
#
# Train:  99%|█████████▉| 2300/2324 [3:04:53<02:00,  5.01s/it]
# Train:  99%|█████████▉| 2300/2324 [3:04:53<02:00,  5.01s/it][INFO:swift] Saving model checkpoint to /mnt/workspace/output/v3-20250928-095853/checkpoint-2300
#
# Train:  99%|█████████▉| 2301/2324 [3:04:59<02:04,  5.42s/it]
# Train:  99%|█████████▉| 2302/2324 [3:05:04<01:54,  5.22s/it]
# Train:  99%|█████████▉| 2303/2324 [3:05:09<01:48,  5.18s/it]
# Train:  99%|█████████▉| 2304/2324 [3:05:13<01:39,  5.00s/it]
# Train:  99%|█████████▉| 2305/2324 [3:05:18<01:33,  4.93s/it]
#
# {'loss': 1.85303802, 'token_acc': 0.59737119, 'grad_norm': 1.70024765, 'learning_rate': 2e-08, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207303, 'epoch': 0.99, 'global_step/max_steps': '2305/2324', 'percentage': '99.18%', 'elapsed_time': '3h 5m 18s', 'remaining_time': '1m 31s'}
#
# Train:  99%|█████████▉| 2305/2324 [3:05:18<01:33,  4.93s/it]
# Train:  99%|█████████▉| 2305/2324 [3:05:18<01:33,  4.93s/it]
# Train:  99%|█████████▉| 2306/2324 [3:05:23<01:28,  4.90s/it]
# Train:  99%|█████████▉| 2307/2324 [3:05:28<01:25,  5.02s/it]
# Train:  99%|█████████▉| 2308/2324 [3:05:34<01:23,  5.21s/it]
# Train:  99%|█████████▉| 2309/2324 [3:05:39<01:16,  5.12s/it]
# Train:  99%|█████████▉| 2310/2324 [3:05:44<01:10,  5.01s/it]
#
# {'loss': 1.72930374, 'token_acc': 0.62551711, 'grad_norm': 1.52184188, 'learning_rate': 1e-08, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207278, 'epoch': 0.99, 'global_step/max_steps': '2310/2324', 'percentage': '99.40%', 'elapsed_time': '3h 5m 44s', 'remaining_time': '1m 7s'}
#
# Train:  99%|█████████▉| 2310/2324 [3:05:44<01:10,  5.01s/it]
# Train:  99%|█████████▉| 2310/2324 [3:05:44<01:10,  5.01s/it]
# Train:  99%|█████████▉| 2311/2324 [3:05:49<01:05,  5.00s/it]
# Train:  99%|█████████▉| 2312/2324 [3:05:53<00:58,  4.91s/it]
# Train: 100%|█████████▉| 2313/2324 [3:05:58<00:52,  4.76s/it]
# Train: 100%|█████████▉| 2314/2324 [3:06:02<00:47,  4.70s/it]
# Train: 100%|█████████▉| 2315/2324 [3:06:07<00:41,  4.60s/it]
#
# {'loss': 1.90418968, 'token_acc': 0.5930317, 'grad_norm': 1.68012834, 'learning_rate': 0.0, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207298, 'epoch': 1.0, 'global_step/max_steps': '2315/2324', 'percentage': '99.61%', 'elapsed_time': '3h 6m 7s', 'remaining_time': '43s'}
#
# Train: 100%|█████████▉| 2315/2324 [3:06:07<00:41,  4.60s/it]
# Train: 100%|█████████▉| 2315/2324 [3:06:07<00:41,  4.60s/it]
# Train: 100%|█████████▉| 2316/2324 [3:06:11<00:37,  4.64s/it]
# Train: 100%|█████████▉| 2317/2324 [3:06:16<00:32,  4.71s/it]
# Train: 100%|█████████▉| 2318/2324 [3:06:20<00:27,  4.53s/it]
# Train: 100%|█████████▉| 2319/2324 [3:06:25<00:22,  4.50s/it]
# Train: 100%|█████████▉| 2320/2324 [3:06:29<00:18,  4.56s/it]
#
# {'loss': 1.95176735, 'token_acc': 0.58407511, 'grad_norm': 2.06682348, 'learning_rate': 0.0, 'memory(GiB)': 21.53, 'train_speed(iter/s)': 0.207322, 'epoch': 1.0, 'global_step/max_steps': '2320/2324', 'percentage': '99.83%', 'elapsed_time': '3h 6m 29s', 'remaining_time': '19s'}
#
# Train: 100%|█████████▉| 2320/2324 [3:06:30<00:18,  4.56s/it]
# Train: 100%|█████████▉| 2320/2324 [3:06:30<00:18,  4.56s/it]
# Train: 100%|█████████▉| 2321/2324 [3:06:34<00:13,  4.61s/it]
# Train: 100%|█████████▉| 2322/2324 [3:06:39<00:09,  4.60s/it]
# Train: 100%|█████████▉| 2323/2324 [3:06:44<00:04,  4.77s/it]
# Train: 100%|██████████| 2324/2324 [3:06:48<00:00,  4.59s/it][INFO:swift] Saving model checkpoint to /mnt/workspace/output/v3-20250928-095853/checkpoint-2324
#
#
# {'train_runtime': 11210.0036, 'train_samples_per_second': 3.317, 'train_steps_per_second': 0.207, 'train_loss': 1.9638301, 'epoch': 1.0, 'global_step/max_steps': '2324/2324', 'percentage': '100.00%', 'elapsed_time': '3h 6m 50s', 'remaining_time': '0s'}
#
# Train: 100%|██████████| 2324/2324 [3:06:50<00:00,  4.59s/it]
# Train: 100%|██████████| 2324/2324 [3:06:50<00:00,  4.59s/it]
# Train: 100%|██████████| 2324/2324 [3:06:50<00:00,  4.82s/it]
# [INFO:swift] last_model_checkpoint: /mnt/workspace/output/v3-20250928-095853/checkpoint-2324
# [INFO:swift] best_model_checkpoint: None
# [INFO:swift] images_dir: /mnt/workspace/output/v3-20250928-095853/images
# [INFO:swift] End time of running main: 2025-09-28 13:08:43.148040
#
#
# 结束时间: 2025-09-28 13:08:44
# 总执行时间: 3:09:59
